# %% [markdown]
# <a href="https://colab.research.google.com/github/Somesh140/Detectron2/blob/main/Custom_Training_Detectron2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detectron2 Custom Training Tutorial
#
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# Welcome to detectron2!

# %% [markdown]
# # Install detectron2

# %%
# !pip install pyyaml==5.1

import torch
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
# Install detectron2 that matches the above pytorch version
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/$CUDA_VERSION/torch$TORCH_VERSION/index.html
# If there is not yet a detectron2 release that matches the given torch + CUDA version, you need to install a different pytorch.
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# exit(0)  # After installation, you may need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp39-cp39-linux_x86_64.whl size=44089 sha256=9ccd61882d2ffd075620955fa46a01f2e6d0cfa523268ccabae64f77c0fa2198
#   Stored in directory: /root/.cache/pip/wheels/68/be/8f/b6c454cd264e0b349b47f8ee00755511f277618af9e5dae20d
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flax 0.6.8 requires PyYAML>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# dask 2022.12.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# Successfully installed pyyaml-5.1
# torch:  2.0 ; cuda:  cu118
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-fwmtqtnu
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-fwmtqtnu
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 1f84ebbf5af96eae71e2c0476d49e9cbdc5b190f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.2.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.12.1)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.9 MB/s eta 0:00:00
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.6 MB/s eta 0:00:00
# Collecting black
#   Downloading black-23.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (5.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (8.1.3)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (3.2.0)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.53.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (67.6.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.17.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->detectron2==0.6) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->detectron2==0.6) (6.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp39-cp39-linux_x86_64.whl size=7801763 sha256=0b41318df2522944fa035c9e0c823d358f97a9fa735bda7e0059283a873ada12
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dj54s81h/wheels/59/b4/83/84bfca751fa4dcc59998468be8688eb50e97408a83af171d42
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61429 sha256=cac6af1a663e6b6e6c04dbf09b13d7afe63f2b10bfb2d36796c45d89ac2f90fd
#   Stored in directory: /root/.cache/pip/wheels/83/42/02/66178d16e5c44dc26d309931834956baeda371956e86fbd876
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=09c5364a9b9be36f2aba83ba35a465d5a95b7318dc93717c86c198ddf87d4ba3
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Classes/Detectron2_detection
# Out:
# /content/drive/MyDrive/Classes/Detectron2_detection

# %%
# !unzip data_detectron2.zip
# Out:
# Archive:  data_detectron2.zip
#    creating: data_detectron2/
#   inflating: data_detectron2/output.json
#    creating: data_detectron2/train/
#   inflating: data_detectron2/train/cam_image1.jpg
#   inflating: data_detectron2/train/cam_image10.jpg
#   inflating: data_detectron2/train/cam_image11.jpg
#   inflating: data_detectron2/train/cam_image12.jpg
#   inflating: data_detectron2/train/cam_image13.jpg
#   inflating: data_detectron2/train/cam_image14.jpg
#   inflating: data_detectron2/train/cam_image15.jpg
#   inflating: data_detectron2/train/cam_image16.jpg
#   inflating: data_detectron2/train/cam_image17.jpg
#   inflating: data_detectron2/train/cam_image18.jpg
#   inflating: data_detectron2/train/cam_image19.jpg
#   inflating: data_detectron2/train/cam_image20.jpg
#   inflating: data_detectron2/train/cam_image21.jpg
#   inflating: data_detectron2/train/cam_image22.jpg
#   inflating: data_detectron2/train/cam_image23.jpg
#   inflating: data_detectron2/train/cam_image24.jpg
#   inflating: data_detectron2/train/cam_image25.jpg
#   inflating: data_detectron2/train/cam_image26.jpg
#   inflating: data_detectron2/train/cam_image27.jpg
#   inflating: data_detectron2/train/cam_image28.jpg
#   inflating: data_detectron2/train/cam_image29.jpg
#   inflating: data_detectron2/train/cam_image3.jpg
#   inflating: data_detectron2/train/cam_image30.jpg
#   inflating: data_detectron2/train/cam_image31.jpg
#   inflating: data_detectron2/train/cam_image32.jpg
#   inflating: data_detectron2/train/cam_image33.jpg
#   inflating: data_detectron2/train/cam_image34.jpg
#   inflating: data_detectron2/train/cam_image35.jpg
#   inflating: data_detectron2/train/cam_image36.jpg
#   inflating: data_detectron2/train/cam_image37.jpg
#   inflating: data_detectron2/train/cam_image38.jpg
#   inflating: data_detectron2/train/cam_image39.jpg
#   inflating: data_detectron2/train/cam_image40.jpg
#   inflating: data_detectron2/train/cam_image41.jpg
#   inflating: data_detectron2/train/cam_image42.jpg
#   inflating: data_detectron2/train/cam_image43.jpg
#   inflating: data_detectron2/train/cam_image44.jpg
#   inflating: data_detectron2/train/cam_image46.jpg
#   inflating: data_detectron2/train/cam_image47.jpg
#   inflating: data_detectron2/train/cam_image48.jpg
#   inflating: data_detectron2/train/cam_image50.jpg
#   inflating: data_detectron2/train/cam_image51.jpg
#   inflating: data_detectron2/train/cam_image52.jpg
#   inflating: data_detectron2/train/cam_image54.jpg
#   inflating: data_detectron2/train/cam_image9.jpg
#   inflating: data_detectron2/train/IMG_2385.JPG
#   inflating: data_detectron2/train/IMG_2386.JPG
#   inflating: data_detectron2/train/IMG_2388.JPG
#   inflating: data_detectron2/train/IMG_2389.JPG
#   inflating: data_detectron2/train/IMG_2390.JPG
#   inflating: data_detectron2/train/IMG_2392.JPG
#   inflating: data_detectron2/train/IMG_2393.JPG
#   inflating: data_detectron2/train/IMG_2394.JPG
#   inflating: data_detectron2/train/IMG_2396.JPG
#   inflating: data_detectron2/train/IMG_2397.JPG
#   inflating: data_detectron2/train/IMG_2398.JPG
#   inflating: data_detectron2/train/IMG_2399.JPG
#   inflating: data_detectron2/train/IMG_2400.JPG
#   inflating: data_detectron2/train/IMG_2401.JPG
#   inflating: data_detectron2/train/IMG_2402.JPG
#   inflating: data_detectron2/train/IMG_2404.JPG
#   inflating: data_detectron2/train/IMG_2405.JPG
#   inflating: data_detectron2/train/IMG_2406.JPG
#   inflating: data_detectron2/train/IMG_2407.JPG
#   inflating: data_detectron2/train/IMG_2408.JPG
#   inflating: data_detectron2/train/IMG_2409.JPG
#   inflating: data_detectron2/train/IMG_2410.JPG
#   inflating: data_detectron2/train/IMG_2411.JPG
#   inflating: data_detectron2/train/IMG_2412.JPG
#   inflating: data_detectron2/train/IMG_2413.JPG
#   inflating: data_detectron2/train/IMG_2414.JPG
#   inflating: data_detectron2/train/IMG_2415.JPG
#   inflating: data_detectron2/train/IMG_2416.JPG
#   inflating: data_detectron2/train/IMG_2417.JPG
#   inflating: data_detectron2/train/IMG_2418.JPG
#   inflating: data_detectron2/train/IMG_2419.JPG
#   inflating: data_detectron2/train/IMG_2420.JPG
#   inflating: data_detectron2/train/IMG_2421.JPG
#   inflating: data_detectron2/train/IMG_2422.JPG
#   inflating: data_detectron2/train/IMG_2423.JPG
#   inflating: data_detectron2/train/IMG_2424.JPG
#   inflating: data_detectron2/train/IMG_2425.JPG
#   inflating: data_detectron2/train/IMG_2426.JPG
#   inflating: data_detectron2/train/IMG_2427.JPG
#   inflating: data_detectron2/train/IMG_2428.JPG
#   inflating: data_detectron2/train/IMG_2429.JPG
#   inflating: data_detectron2/train/IMG_2430.JPG
#   inflating: data_detectron2/train/IMG_2431.JPG
#   inflating: data_detectron2/train/IMG_2434.JPG
#   inflating: data_detectron2/train/IMG_2437.JPG
#   inflating: data_detectron2/train/IMG_2439.JPG
#   inflating: data_detectron2/train/IMG_2441.JPG
#   inflating: data_detectron2/train/IMG_2442.JPG
#   inflating: data_detectron2/train/IMG_2443.JPG
#   inflating: data_detectron2/train/IMG_2445.JPG
#   inflating: data_detectron2/train/IMG_2446.JPG
#   inflating: data_detectron2/train/IMG_2447.JPG
#   inflating: data_detectron2/train/IMG_2448.JPG
#   inflating: data_detectron2/train/IMG_2449.JPG
#   inflating: data_detectron2/train/IMG_2450.JPG
#   inflating: data_detectron2/train/IMG_2451.JPG
#   inflating: data_detectron2/train/IMG_2452.JPG
#   inflating: data_detectron2/train/IMG_2453.JPG
#   inflating: data_detectron2/train/IMG_2454.JPG
#   inflating: data_detectron2/train/IMG_2455.JPG
#   inflating: data_detectron2/train/IMG_2456.JPG
#   inflating: data_detectron2/train/IMG_2457.JPG
#   inflating: data_detectron2/train/IMG_2458.JPG
#   inflating: data_detectron2/train/IMG_2459.JPG
#   inflating: data_detectron2/train/IMG_2460.JPG
#   inflating: data_detectron2/train/IMG_2462.JPG
#   inflating: data_detectron2/train/IMG_2464.JPG
#   inflating: data_detectron2/train/IMG_2465.JPG
#   inflating: data_detectron2/train/IMG_2466.JPG
#   inflating: data_detectron2/train/IMG_2467.JPG
#   inflating: data_detectron2/train/IMG_2468.JPG
#   inflating: data_detectron2/train/IMG_2469.JPG
#   inflating: data_detectron2/train/IMG_2471.JPG
#   inflating: data_detectron2/train/IMG_2472.JPG
#   inflating: data_detectron2/train/IMG_2473.JPG
#   inflating: data_detectron2/train/IMG_2474.JPG
#   inflating: data_detectron2/train/IMG_2475.JPG
#   inflating: data_detectron2/train/IMG_2477.JPG
#   inflating: data_detectron2/train/IMG_2478.JPG
#   inflating: data_detectron2/train/IMG_2480.JPG
#   inflating: data_detectron2/train/IMG_2481.JPG
#   inflating: data_detectron2/train/IMG_2483.JPG
#   inflating: data_detectron2/train/IMG_2484.JPG
#   inflating: data_detectron2/train/IMG_2486.JPG
#   inflating: data_detectron2/train/IMG_2487.JPG
#   inflating: data_detectron2/train/IMG_2488.JPG
#   inflating: data_detectron2/train/IMG_2489.JPG
#   inflating: data_detectron2/train/IMG_2490.JPG
#   inflating: data_detectron2/train/IMG_2491.JPG
#   inflating: data_detectron2/train/IMG_2492.JPG
#   inflating: data_detectron2/train/IMG_2493.JPG
#   inflating: data_detectron2/train/IMG_2494.JPG
#   inflating: data_detectron2/train/IMG_2495.JPG
#   inflating: data_detectron2/train/IMG_2496.JPG
#   inflating: data_detectron2/train/IMG_2497.JPG
#   inflating: data_detectron2/train/IMG_2498.JPG
#   inflating: data_detectron2/train/IMG_2499.JPG
#   inflating: data_detectron2/train/IMG_2500.JPG
#   inflating: data_detectron2/train/IMG_2501.JPG
#   inflating: data_detectron2/train/IMG_2502.JPG
#   inflating: data_detectron2/train/IMG_2503.JPG
#   inflating: data_detectron2/train/IMG_2504.JPG
#   inflating: data_detectron2/train/IMG_2505.JPG
#   inflating: data_detectron2/train/IMG_2506.JPG
#   inflating: data_detectron2/train/IMG_2507.JPG
#   inflating: data_detectron2/train/IMG_2508.JPG
#   inflating: data_detectron2/train/IMG_2509.JPG
#   inflating: data_detectron2/train/IMG_2511.JPG
#   inflating: data_detectron2/train/IMG_2512.JPG
#   inflating: data_detectron2/train/IMG_2513.JPG
#   inflating: data_detectron2/train/IMG_2514.JPG
#   inflating: data_detectron2/train/IMG_2515.JPG
#   inflating: data_detectron2/train/IMG_2516.JPG
#   inflating: data_detectron2/train/IMG_2517.JPG
#   inflating: data_detectron2/train/IMG_2518.JPG
#   inflating: data_detectron2/train/IMG_2519.JPG
#   inflating: data_detectron2/train/IMG_2520.JPG
#   inflating: data_detectron2/train/IMG_2521.JPG
#   inflating: data_detectron2/train/IMG_2522.JPG
#   inflating: data_detectron2/train/IMG_2523.JPG
#   inflating: data_detectron2/train/IMG_2524.JPG
#   inflating: data_detectron2/train/IMG_2525.JPG
#   inflating: data_detectron2/train/IMG_2526.JPG
#   inflating: data_detectron2/train/IMG_2527.JPG
#   inflating: data_detectron2/train/IMG_2528.JPG
#   inflating: data_detectron2/train/IMG_2529.JPG
#   inflating: data_detectron2/train/IMG_2533.JPG
#   inflating: data_detectron2/train/IMG_2535.JPG
#   inflating: data_detectron2/train/IMG_2536.JPG
#   inflating: data_detectron2/train/IMG_2537.JPG
#   inflating: data_detectron2/train/IMG_2538.JPG
#   inflating: data_detectron2/train/IMG_2542.JPG
#   inflating: data_detectron2/train/IMG_2543.JPG
#   inflating: data_detectron2/train/IMG_2545.JPG
#   inflating: data_detectron2/train/IMG_2546.JPG
#   inflating: data_detectron2/train/IMG_2548.JPG
#   inflating: data_detectron2/train/IMG_2549.JPG
#   inflating: data_detectron2/train/IMG_2552.JPG
#   inflating: data_detectron2/train/IMG_2553.JPG
#   inflating: data_detectron2/train/IMG_2556.JPG
#   inflating: data_detectron2/train/IMG_2558.JPG
#   inflating: data_detectron2/train/IMG_2559.JPG
#   inflating: data_detectron2/train/IMG_2562.JPG
#   inflating: data_detectron2/train/IMG_2563.JPG
#   inflating: data_detectron2/train/IMG_2565.JPG
#   inflating: data_detectron2/train/IMG_2566.JPG
#   inflating: data_detectron2/train/IMG_2567.JPG
#   inflating: data_detectron2/train/IMG_2569.JPG
#   inflating: data_detectron2/train/IMG_2570.JPG
#   inflating: data_detectron2/train/IMG_2572.JPG
#   inflating: data_detectron2/train/IMG_2574.JPG
#   inflating: data_detectron2/train/IMG_2576.JPG
#   inflating: data_detectron2/train/IMG_2577.JPG
#   inflating: data_detectron2/train/IMG_2578.JPG
#   inflating: data_detectron2/train/IMG_2579.JPG
#   inflating: data_detectron2/train/IMG_2581.JPG
#   inflating: data_detectron2/train/IMG_2582.JPG
#   inflating: data_detectron2/train/IMG_2584.JPG
#   inflating: data_detectron2/train/IMG_2586.JPG
#   inflating: data_detectron2/train/IMG_2587.JPG
#   inflating: data_detectron2/train/IMG_2588.JPG
#   inflating: data_detectron2/train/IMG_2589.JPG
#   inflating: data_detectron2/train/IMG_2590.JPG
#   inflating: data_detectron2/train/IMG_2593.JPG
#   inflating: data_detectron2/train/IMG_2596.JPG
#   inflating: data_detectron2/train/IMG_2597.JPG
#   inflating: data_detectron2/train/IMG_2599.JPG
#   inflating: data_detectron2/train/IMG_2601.JPG
#   inflating: data_detectron2/train/IMG_2602.JPG
#   inflating: data_detectron2/train/IMG_2603.JPG
#   inflating: data_detectron2/train/IMG_2605.JPG
#   inflating: data_detectron2/train/IMG_2607.JPG
#   inflating: data_detectron2/train/IMG_2608.JPG
#   inflating: data_detectron2/train/IMG_2609.JPG
#   inflating: data_detectron2/train/IMG_2610.JPG
#   inflating: data_detectron2/train/IMG_2611.JPG
#   inflating: data_detectron2/train/IMG_2612.JPG
#   inflating: data_detectron2/train/IMG_2613.JPG
#   inflating: data_detectron2/train/IMG_2614.JPG
#   inflating: data_detectron2/train/IMG_2615.JPG
#   inflating: data_detectron2/train/IMG_2616.JPG
#   inflating: data_detectron2/train/IMG_2617.JPG
#   inflating: data_detectron2/train/IMG_2618.JPG
#   inflating: data_detectron2/train/IMG_2619.JPG
#   inflating: data_detectron2/train/IMG_2620.JPG
#   inflating: data_detectron2/train/IMG_2621.JPG
#   inflating: data_detectron2/train/IMG_2622.JPG
#   inflating: data_detectron2/train/IMG_2623.JPG
#   inflating: data_detectron2/train/IMG_2624.JPG
#   inflating: data_detectron2/train/IMG_2626.JPG
#   inflating: data_detectron2/train/IMG_2627.JPG
#   inflating: data_detectron2/train/IMG_2628.JPG
#   inflating: data_detectron2/train/IMG_2629.JPG
#   inflating: data_detectron2/train/IMG_2630.JPG
#   inflating: data_detectron2/train/IMG_2631.JPG
#   inflating: data_detectron2/train/IMG_2632.JPG
#   inflating: data_detectron2/train/IMG_2633.JPG
#   inflating: data_detectron2/train/IMG_2635.JPG
#   inflating: data_detectron2/train/IMG_2637.JPG
#   inflating: data_detectron2/train/IMG_2638.JPG
#   inflating: data_detectron2/train/IMG_2641.JPG
#   inflating: data_detectron2/train/IMG_2642.JPG
#   inflating: data_detectron2/train/IMG_2643.JPG
#   inflating: data_detectron2/train/IMG_2644.JPG
#   inflating: data_detectron2/train/IMG_2645.JPG
#   inflating: data_detectron2/train/IMG_2648.JPG
#   inflating: data_detectron2/train/IMG_2649.JPG
#   inflating: data_detectron2/train/IMG_2650.JPG
#   inflating: data_detectron2/train/IMG_2652.JPG
#   inflating: data_detectron2/train/IMG_2653.JPG
#   inflating: data_detectron2/train/IMG_2655.JPG
#   inflating: data_detectron2/train/IMG_2657.JPG
#   inflating: data_detectron2/train/IMG_2658.JPG
#   inflating: data_detectron2/train/IMG_2659.JPG
#   inflating: data_detectron2/train/IMG_2660.JPG
#   inflating: data_detectron2/train/IMG_2661.JPG
#   inflating: data_detectron2/train/IMG_2663.JPG
#   inflating: data_detectron2/train/IMG_2664.JPG
#   inflating: data_detectron2/train/IMG_2665.JPG
#   inflating: data_detectron2/train/IMG_2666.JPG
#   inflating: data_detectron2/train/IMG_2667.JPG
#   inflating: data_detectron2/train/IMG_2668.JPG
#   inflating: data_detectron2/train/IMG_2669.JPG
#   inflating: data_detectron2/train/IMG_2671.JPG
#   inflating: data_detectron2/train/IMG_2672.JPG
#   inflating: data_detectron2/train/IMG_2673.JPG
#   inflating: data_detectron2/train/IMG_2674.JPG
#   inflating: data_detectron2/train/IMG_2679.JPG
#   inflating: data_detectron2/train/IMG_2680.JPG
#   inflating: data_detectron2/train/IMG_2681.JPG
#   inflating: data_detectron2/train/IMG_2682.JPG
#   inflating: data_detectron2/train/IMG_2683.JPG
#   inflating: data_detectron2/train/IMG_2684.JPG
#   inflating: data_detectron2/train/IMG_2685.JPG
#   inflating: data_detectron2/train/IMG_2687.JPG
#   inflating: data_detectron2/train/IMG_2689.JPG
#   inflating: data_detectron2/train/IMG_2690.JPG
#   inflating: data_detectron2/train/IMG_2691.JPG
#   inflating: data_detectron2/train/IMG_2692.JPG
#   inflating: data_detectron2/train/IMG_2693.JPG
#   inflating: data_detectron2/train/IMG_2694.JPG
#   inflating: data_detectron2/train/IMG_2695.JPG
#   inflating: data_detectron2/train/IMG_2696.JPG
#   inflating: data_detectron2/train/IMG_2697.JPG
#   inflating: data_detectron2/train/IMG_2698.JPG
#   inflating: data_detectron2/train/IMG_2699.JPG
#   inflating: data_detectron2/train/IMG_2700.JPG
#   inflating: data_detectron2/train/IMG_2701.JPG
#   inflating: data_detectron2/train/IMG_2702.JPG
#   inflating: data_detectron2/train/IMG_2703.JPG
#   inflating: data_detectron2/train/IMG_2704.JPG

# %%
# %cd data_detectron2
# Out:
# /content/drive/MyDrive/Classes/Detectron2_detection/data_detectron2

# %% [markdown]
# # Register data

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("customtrain1", {}, "./output.json", "./train")

# %%
sample_metadata = MetadataCatalog.get("customtrain1")
dataset_dicts = DatasetCatalog.get("customtrain1")
# Out:
# WARNING [04/17 12:38:27 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/17 12:38:27 d2.data.datasets.coco]: Loaded 290 images in COCO format from ./output.json

# %%
import random

for d in random.sample(dataset_dicts, 4):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=sample_metadata, scale=1.2)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=453x604 at 0x7F272F5D6DF0>
# <PIL.Image.Image image mode=RGB size=453x604 at 0x7F272F70FA00>
# <PIL.Image.Image image mode=RGB size=453x604 at 0x7F272F5FD1C0>
# <PIL.Image.Image image mode=RGB size=453x604 at 0x7F272E4DE7F0>

# %% [markdown]
# # Training

# %%
from detectron2.engine import DefaultTrainer

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("customtrain1",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.0025  # pick a good LR
cfg.SOLVER.MAX_ITER = 300    # 300 iterations seems good enough for this toy dataset; you will need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 6  # (see https://detectron2.readthedocs.io/tutorials/datasets.html#update-the-config-for-new-datasets)
# NOTE: this config means the number of classes, but a few popular unofficial tutorials incorrect uses num_classes+1 here.

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=True) #to resume training from runtime
trainer.train()
# Out:
# [04/17 13:54:30 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=7, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )
# WARNING [04/17 13:54:30 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/17 13:54:30 d2.data.datasets.coco]: Loaded 290 images in COCO format from ./output.json
# [04/17 13:54:30 d2.data.build]: Removed 0 images with no usable annotations. 290 images left.
# [04/17 13:54:30 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/17 13:54:30 d2.data.build]: Using training sampler TrainingSampler
# [04/17 13:54:30 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/17 13:54:30 d2.data.common]: Serializing 290 elements to byte tensors and concatenating them all ...
# [04/17 13:54:30 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [04/17 13:54:30 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [04/17 13:54:30 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# [04/17 13:54:30 d2.engine.hooks]: Loading scheduler from state_dict ...
# [04/17 13:54:30 d2.engine.train_loop]: Starting training from iteration 100
# [04/17 13:54:39 d2.utils.events]:  eta: 0:01:11  iter: 119  total_loss: 0.5864  loss_cls: 0.3056  loss_box_reg: 0.2523  loss_rpn_cls: 0.000241  loss_rpn_loc: 0.004082    time: 0.4156  last_time: 0.3992  data_time: 0.0201  last_data_time: 0.0190   lr: 0.00099318  max_mem: 2704M
# [04/17 13:54:47 d2.utils.events]:  eta: 0:01:03  iter: 139  total_loss: 0.49  loss_cls: 0.309  loss_box_reg: 0.1749  loss_rpn_cls: 0.0001421  loss_rpn_loc: 0.004357    time: 0.4160  last_time: 0.3170  data_time: 0.0106  last_data_time: 0.0034   lr: 0.0011597  max_mem: 2707M
# [04/17 13:54:55 d2.utils.events]:  eta: 0:00:54  iter: 159  total_loss: 0.4483  loss_cls: 0.2425  loss_box_reg: 0.1973  loss_rpn_cls: 0.0001185  loss_rpn_loc: 0.003687    time: 0.4084  last_time: 0.3929  data_time: 0.0114  last_data_time: 0.0065   lr: 0.0013262  max_mem: 2707M
# [04/17 13:55:03 d2.utils.events]:  eta: 0:00:47  iter: 179  total_loss: 0.4811  loss_cls: 0.2767  loss_box_reg: 0.1923  loss_rpn_cls: 0.0002906  loss_rpn_loc: 0.003791    time: 0.4100  last_time: 0.3992  data_time: 0.0081  last_data_time: 0.0088   lr: 0.0014927  max_mem: 2707M
# [04/17 13:55:12 d2.utils.events]:  eta: 0:00:39  iter: 199  total_loss: 0.4136  loss_cls: 0.2111  loss_box_reg: 0.1811  loss_rpn_cls: 6.473e-05  loss_rpn_loc: 0.002598    time: 0.4111  last_time: 0.4365  data_time: 0.0095  last_data_time: 0.0090   lr: 0.0016592  max_mem: 2707M
# [04/17 13:55:20 d2.utils.events]:  eta: 0:00:31  iter: 219  total_loss: 0.4601  loss_cls: 0.2741  loss_box_reg: 0.19  loss_rpn_cls: 0.0001256  loss_rpn_loc: 0.002861    time: 0.4108  last_time: 0.3277  data_time: 0.0100  last_data_time: 0.0146   lr: 0.0018257  max_mem: 2707M
# [04/17 13:55:28 d2.utils.events]:  eta: 0:00:23  iter: 239  total_loss: 0.4336  loss_cls: 0.2289  loss_box_reg: 0.1835  loss_rpn_cls: 0.0001767  loss_rpn_loc: 0.004419    time: 0.4077  last_time: 0.3477  data_time: 0.0082  last_data_time: 0.0086   lr: 0.0019922  max_mem: 2707M
# [04/17 13:55:36 d2.utils.events]:  eta: 0:00:15  iter: 259  total_loss: 0.5237  loss_cls: 0.2863  loss_box_reg: 0.2239  loss_rpn_cls: 9.811e-05  loss_rpn_loc: 0.004356    time: 0.4075  last_time: 0.5005  data_time: 0.0085  last_data_time: 0.0076   lr: 0.0021587  max_mem: 2707M
# [04/17 13:55:44 d2.utils.events]:  eta: 0:00:07  iter: 279  total_loss: 0.4115  loss_cls: 0.2312  loss_box_reg: 0.1728  loss_rpn_cls: 0.0002846  loss_rpn_loc: 0.003398    time: 0.4070  last_time: 0.3802  data_time: 0.0087  last_data_time: 0.0121   lr: 0.0023252  max_mem: 2707M
# [04/17 13:55:53 d2.utils.events]:  eta: 0:00:00  iter: 299  total_loss: 0.4804  loss_cls: 0.2533  loss_box_reg: 0.2019  loss_rpn_cls: 0.0003547  loss_rpn_loc: 0.002804    time: 0.4052  last_time: 0.3975  data_time: 0.0112  last_data_time: 0.0065   lr: 0.0024917  max_mem: 2707M
# [04/17 13:55:53 d2.engine.hooks]: Overall training speed: 198 iterations in 0:01:20 (0.4052 s / it)
# [04/17 13:55:53 d2.engine.hooks]: Total training time: 0:01:21 (0:00:01 on hooks)

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
cfg.DATASETS.TEST = ("customtrain1", )
predictor = DefaultPredictor(cfg)
# Out:
# [04/17 13:56:07 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...

# %%
from detectron2.utils.visualizer import ColorMode

for d in random.sample(dataset_dicts, 4):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=sample_metadata, 
                   scale=0.8, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=302x403 at 0x7F2560CD1190>
# <PIL.Image.Image image mode=RGB size=302x403 at 0x7F2560D73340>
# <PIL.Image.Image image mode=RGB size=302x403 at 0x7F272E4AD640>
# <PIL.Image.Image image mode=RGB size=302x403 at 0x7F272E1A8400>

# %%
# %cd data_detectron2
# Out:
# [Errno 2] No such file or directory: 'data_detectron2'
# /content/drive/MyDrive/Classes/Detectron2_detection/data_detectron2

# %%
pwd
# Out:
# '/content/drive/MyDrive/Classes/Detectron2_detection/data_detectron2'

# %% [markdown]
# # Evaluation

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("customtrain1", output_dir= "./output")
val_loader = build_detection_test_loader(cfg, "customtrain1")
print(inference_on_dataset(predictor.model, val_loader, evaluator))
# Out:
# WARNING [04/17 13:58:44 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/17 13:58:44 d2.data.datasets.coco]: Loaded 290 images in COCO format from ./output.json
# [04/17 13:58:44 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [04/17 13:58:44 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/17 13:58:44 d2.data.common]: Serializing 290 elements to byte tensors and concatenating them all ...
# [04/17 13:58:44 d2.data.common]: Serialized dataset takes 0.07 MiB
# [04/17 13:58:44 d2.evaluation.evaluator]: Start inference on 290 batches
# [04/17 13:58:46 d2.evaluation.evaluator]: Inference done 11/290. Dataloading: 0.0032 s/iter. Inference: 0.0984 s/iter. Eval: 0.0003 s/iter. Total: 0.1020 s/iter. ETA=0:00:28
# [04/17 13:58:51 d2.evaluation.evaluator]: Inference done 61/290. Dataloading: 0.0021 s/iter. Inference: 0.0988 s/iter. Eval: 0.0002 s/iter. Total: 0.1013 s/iter. ETA=0:00:23
# [04/17 13:58:56 d2.evaluation.evaluator]: Inference done 111/290. Dataloading: 0.0021 s/iter. Inference: 0.0990 s/iter. Eval: 0.0002 s/iter. Total: 0.1013 s/iter. ETA=0:00:18
# [04/17 13:59:01 d2.evaluation.evaluator]: Inference done 158/290. Dataloading: 0.0039 s/iter. Inference: 0.0988 s/iter. Eval: 0.0002 s/iter. Total: 0.1029 s/iter. ETA=0:00:13
# [04/17 13:59:06 d2.evaluation.evaluator]: Inference done 208/290. Dataloading: 0.0034 s/iter. Inference: 0.0988 s/iter. Eval: 0.0002 s/iter. Total: 0.1026 s/iter. ETA=0:00:08
# [04/17 13:59:11 d2.evaluation.evaluator]: Inference done 256/290. Dataloading: 0.0032 s/iter. Inference: 0.0995 s/iter. Eval: 0.0002 s/iter. Total: 0.1030 s/iter. ETA=0:00:03
# [04/17 13:59:16 d2.evaluation.evaluator]: Total inference time: 0:00:30.543248 (0.107169 s / iter per device, on 1 devices)
# [04/17 13:59:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:29 (0.102775 s / iter per device, on 1 devices)
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/17 13:59:16 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [04/17 13:59:16 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [04/17 13:59:16 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/17 13:59:16 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.307
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 24.202 | 30.509 | 29.621 |  nan  | 32.166 | 24.010 |
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/17 13:59:16 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP    | category   | AP     |
# |:-----------|:-------|:-----------|:------|:-----------|:-------|
# | ace        | 82.670 | jack       | 5.564 | king       | 6.500  |
# | nine       | 0.000  | queen      | 0.000 | ten        | 50.476 |
# OrderedDict([('bbox', {'AP': 24.20170989718834, 'AP50': 30.50936120163267, 'AP75': 29.62052621797058, 'APs': nan, 'APm': 32.166116611661174, 'APl': 24.009609937660166, 'AP-ace': 82.67013773018577, 'AP-jack': 5.564318931893189, 'AP-king': 6.5, 'AP-nine': 0.0, 'AP-queen': 0.0, 'AP-ten': 50.47580272105107})])

# %%
#Ap-average precision if AP is greater than 80% then it is a good model
#AR-average recall

# %% [markdown]
# ### Getting the custom config file

# %%
pwd
# Out:
# '/content/drive/MyDrive/Classes/Detectron2_detection/data_detectron2'

# %%
f = open('config.yml', 'w')
f.write(cfg.dump())
f.close()
